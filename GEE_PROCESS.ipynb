# %%
import ee
import geemap
import gee.gee_objects as gee
# Out:
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_7TDKVSyKvBdmMqW?ref=4i2o6

# %%
vector_BLS = ee.FeatureCollection('projects/saw-ucdavis/assets/BLS')
vector_RIP720 = ee.FeatureCollection('projects/saw-ucdavis/assets/RIP_720')

vector = vector_RIP720
farm = 'RIP720'
first_date = '2018-01-01'
last_date = '2020-12-31'
crs = 'EPSG:32610'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
S2_BLS = (gee.Sentinel2(farm=farm, aoi=vector)
          .filter_date(first_date, last_date)
          .cloud_mask())

S2_BLS = S2_BLS.clip()
S2_BLS.percentage_pixel_free_clouds(band='B4', scale=10, crs=crs)
S2_BLS.filter_by_feature(filter='gte', name='percentage_pixel_free_clouds', value=99)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
feature = S2_BLS.get_feature('percentage_pixel_free_clouds', unique=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 feature = S2_BLS.get_feature('percentage_pixel_free_clouds', unique=False)
#
# File ~\Desktop\3SEB_improvement\gee\gee_objects.py:114, in Sentinel2.get_feature(self, feature, unique)
#     113 def get_feature(self, feature, unique=True):
# --> 114     output = self.gee_image_collection.aggregate_array(feature).getInfo()
#     115     if unique:
#     116         output = np.unique(output)
#
# File ~\.conda\envs\SEB_models\lib\site-packages\ee\computedobject.py:107, in ComputedObject.getInfo(self)
#     101 def getInfo(self) -> Any | None:
#     102   """Fetch and return information about this object.
#     103
#     104   Returns:
#     105     The object can evaluate to anything.
#     106   """
# --> 107   return data.computeValue(self)
#
# File ~\.conda\envs\SEB_models\lib\site-packages\ee\data.py:1128, in computeValue(obj)
#    1125 body = {'expression': serializer.encode(obj, for_cloud_api=True)}
#    1126 _maybe_populate_workload_tag(body)
# -> 1128 return _execute_cloud_call(
#    1129     _get_cloud_projects()
#    1130     .value()
#    1131     .compute(body=body, project=_get_projects_path(), prettyPrint=False)
#    1132 )['result']
#
# File ~\.conda\envs\SEB_models\lib\site-packages\ee\data.py:409, in _execute_cloud_call(call, num_retries)
#     407 num_retries = _max_retries if num_retries is None else num_retries
#     408 try:
# --> 409   return call.execute(num_retries=num_retries)
#     410 except googleapiclient.errors.HttpError as e:
#     411   raise _translate_cloud_exception(e)
#
# File ~\.conda\envs\SEB_models\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\.conda\envs\SEB_models\lib\site-packages\googleapiclient\http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File ~\.conda\envs\SEB_models\lib\site-packages\googleapiclient\http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File ~\.conda\envs\SEB_models\lib\site-packages\google_auth_httplib2.py:218, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     215     body_stream_position = body.tell()
#     217 # Make the request.
# --> 218 response, content = self.http.request(
#     219     uri,
#     220     method,
#     221     body=body,
#     222     headers=request_headers,
#     223     redirections=redirections,
#     224     connection_type=connection_type,
#     225     **kwargs
#     226 )
#     228 # If the response indicated that the credentials needed to be
#     229 # refreshed, then refresh the credentials and re-attempt the
#     230 # request.
#     231 # A stored token may expire between the time it is retrieved and
#     232 # the time the request is made, so we may need to try twice.
#     233 if (
#     234     response.status in self._refresh_status_codes
#     235     and _credential_refresh_attempt < self._max_refresh_attempts
#     236 ):
#
# File ~\.conda\envs\SEB_models\lib\site-packages\ee\_cloud_api_utils.py:71, in _Http.request(***failed resolving arguments***)
#      64 del redirections  # Ignored
#      66 try:
#      67   # googleapiclient is expecting an httplib2 object, and doesn't include
#      68   # requests error in the list of transient errors. Therefore, transient
#      69   # requests errors should be converted to kinds that googleapiclient
#      70   # consider transient.
# ---> 71   response = self._session.request(
#      72       method, uri, data=body, headers=headers, timeout=self._timeout
#      73   )
#      74 except requests.exceptions.ConnectionError as connection_error:
#      75   raise ConnectionError(connection_error) from connection_error
#
# File ~\.conda\envs\SEB_models\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\.conda\envs\SEB_models\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\.conda\envs\SEB_models\lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~\.conda\envs\SEB_models\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\.conda\envs\SEB_models\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\.conda\envs\SEB_models\lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~\.conda\envs\SEB_models\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~\.conda\envs\SEB_models\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\.conda\envs\SEB_models\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\.conda\envs\SEB_models\lib\socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File ~\.conda\envs\SEB_models\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~\.conda\envs\SEB_models\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
out_dir = rf'C:\Users\mqalborn\Desktop\ET_3SEB\GRAPEX\Sentinel2'
geemap.ee_export_image_collection(
    S2_BLS.gee_image_collection.select('B.*'),
    scale=10,
    region=S2_BLS.aoi.geometry(),
    out_dir=out_dir)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#
tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/saw-ucdavis/thumbnails/0841881e2ec638176e1181fd90b6ab56-f8723f1cd8fbbce227281ce92e21dcc5:getPixels
# Please wait ...
# Data downloaded to C:\Users\mqalborn\Desktop\ET_3SEB\GRAPEX\Sentinel2\20201207T184751_20201207T185023_T11SKA.tif

# %%
Map = geemap.Map()
Map.centerObject(vector, zoom=16)

vis_params = {
    'bands': ['B4', 'B3', 'B2'], # False color composite (NIR, Red, Green)
    'min': 0.0,
    'max': 3000,
}

Map.add_layer(S2image, vis_params, "Sentinel2")
# Map.add_layer(vector, {'color': 'FF0000', 'opacity': 0.5}, "BLS")

Map

# %%
data = S2_BLS.count_pixels_features(index='B4', scale=10, crs='EPSG:32610')

# %%
filename = rf'C:\Users\mqalborn\Desktop\ET_3SEB\raster/example.tif'
geemap.ee_export_image(S2image, filename=filename, scale=10, region=S2_BLS.aoi.geometry(),  file_per_band=False)

# %%
out_dir = rf'C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2'
geemap.ee_export_image_collection(
    S2_BLS.gee_image_collection.select('B.*'),
    scale=10,
    region=S2_BLS.aoi.geometry(),
    out_dir=out_dir)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total number of images: 73
#
# Exporting 1/73: C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240104T185801_20240104T185757_T10SFH.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/saw-ucdavis/thumbnails/80d3d9ace12eec20b380746b8c8f303d-1b69678934901489a61662fb032fac40:getPixels
# Please wait ...
# Data downloaded to C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240104T185801_20240104T185757_T10SFH.tif
#
#
# Exporting 2/73: C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240109T185749_20240109T185748_T10SFH.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/saw-ucdavis/thumbnails/9f74cfe75e5f25a5b14293cbca61485f-23fa701e0877c3626e143cadd650c5d1:getPixels
# Please wait ...
# Data downloaded to C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240109T185749_20240109T185748_T10SFH.tif
#
#
# Exporting 3/73: C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240114T185731_20240114T185729_T10SFH.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/saw-ucdavis/thumbnails/12a6468e8bda3b68dc0a87eec8283a83-30a2a67977e8fb4b1385c0e88cc3ff4c:getPixels
# Please wait ...
# Data downloaded to C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240114T185731_20240114T185729_T10SFH.tif
#
#
# Exporting 4/73: C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240119T185719_20240119T185717_T10SFH.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/saw-ucdavis/thumbnails/742b9f7918532ba4270f39bf63546693-5dbfa1a5faeacaad3371b69453c97907:getPixels
# Please wait ...
# Data downloaded to C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240119T185719_20240119T185717_T10SFH.tif
#
#
# Exporting 5/73: C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240124T185651_20240124T190113_T10SFH.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/saw-ucdavis/thumbnails/78a411eeb15638d77ed6c9180ae569f4-8919f89dd83287b3ca966309e50a6a6f:getPixels
# Please wait ...
# Data downloaded to C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240124T185651_20240124T190113_T10SFH.tif
#
#
# Exporting 6/73: C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240129T185629_20240129T185629_T10SFH.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/saw-ucdavis/thumbnails/803d0faffde9f3cffb0d14f6d835c6d1-7eae64f8424343390d4ba8b621630706:getPixels
# Please wait ...
# Data downloaded to C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240129T185629_20240129T185629_T10SFH.tif
#
#
# Exporting 7/73: C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240203T185601_20240203T185601_T10SFH.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/saw-ucdavis/thumbnails/1c0e0e03c161c5be3c4cce753ac65ff3-58139661c0a10100443ec7238b3a80ab:getPixels
# Please wait ...
# Data downloaded to C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240203T185601_20240203T185601_T10SFH.tif
#
#
# Exporting 8/73: C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240208T185539_20240208T185540_T10SFH.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/saw-ucdavis/thumbnails/381f0ed440f841e7ceae3eadefee0c6b-758845a88b5f118ad514d9955e059583:getPixels
# Please wait ...
# Data downloaded to C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240208T185539_20240208T185540_T10SFH.tif
#
#
# Exporting 9/73: C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240218T185439_20240218T190309_T10SFH.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/saw-ucdavis/thumbnails/1df91332ace47890c63de1dbb0b95a28-e27d3431ed6ed105b194d5ac88320ef7:getPixels
# Please wait ...
# Data downloaded to C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240218T185439_20240218T190309_T10SFH.tif
#
#
# Exporting 10/73: C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240223T185401_20240223T185748_T10SFH.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/saw-ucdavis/thumbnails/d3ba4955d47b98b05abd56affeb0f944-aadce208f64ec766aa672558704f7cf0:getPixels
# Please wait ...
# Data downloaded to C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240223T185401_20240223T185748_T10SFH.tif
#
#
# Exporting 11/73: C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240228T185319_20240228T185422_T10SFH.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/saw-ucdavis/thumbnails/2b824b23142f0fc877e5856b8efe7534-b33df4c8000ac91a923234daea9316a0:getPixels
# Please wait ...
# Data downloaded to C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240228T185319_20240228T185422_T10SFH.tif
#
#
# Exporting 12/73: C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2\20240304T185251_20240304T190250_T10SFH.tif
# Generating URL ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 out_dir = rf'C:\Users\mqalborn\Desktop\ET_3SEB\PISTACHIO\Sentinel2'
# ----> 2 geemap.ee_export_image_collection(
#       3     S2_BLS.gee_image_collection.select('B.*'),
#       4     scale=10,
#       5     region=S2_BLS.aoi.geometry(),
#       6     out_dir=out_dir)
#
# File ~\.conda\envs\SEB_models\lib\site-packages\geemap\common.py:223, in ee_export_image_collection(ee_object, out_dir, scale, crs, crs_transform, region, dimensions, file_per_band, format, unmask_value, filenames, timeout, proxies, verbose)
#     221         if verbose:
#     222             print(f"Exporting {i + 1}/{count}: {filename}")
# --> 223         ee_export_image(
#     224             image,
#     225             filename=filename,
#     226             scale=scale,
#     227             crs=crs,
#     228             crs_transform=crs_transform,
#     229             region=region,
#     230             dimensions=dimensions,
#     231             file_per_band=file_per_band,
#     232             format=format,
#     233             unmask_value=unmask_value,
#     234             timeout=timeout,
#     235             proxies=proxies,
#     236         )
#     237         print("\n")
#     239 except Exception as e:
#
# File ~\.conda\envs\SEB_models\lib\site-packages\geemap\common.py:115, in ee_export_image(ee_object, filename, scale, crs, crs_transform, region, dimensions, file_per_band, format, unzip, unmask_value, timeout, proxies, verbose)
#     112     params["format"] = format
#     114 try:
# --> 115     url = ee_object.getDownloadURL(params)
#     116 except Exception as e:
#     117     print("An error occurred while downloading.")
#
# File ~\.conda\envs\SEB_models\lib\site-packages\ee\image.py:517, in Image.getDownloadURL(self, params)
#     515 request = params or {}
#     516 request['image'] = self
# --> 517 return data.makeDownloadUrl(data.getDownloadId(request))
#
# File ~\.conda\envs\SEB_models\lib\site-packages\ee\data.py:1381, in getDownloadId(params)
#    1376 queryParams = {
#    1377     'fields': 'name',
#    1378     'body': request,
#    1379 }
#    1380 _maybe_populate_workload_tag(queryParams)
# -> 1381 result = _execute_cloud_call(
#    1382     _get_cloud_projects()
#    1383     .thumbnails()
#    1384     .create(parent=_get_projects_path(), **queryParams)
#    1385 )
#    1386 return {'docid': result['name'], 'token': ''}
#
# File ~\.conda\envs\SEB_models\lib\site-packages\ee\data.py:409, in _execute_cloud_call(call, num_retries)
#     407 num_retries = _max_retries if num_retries is None else num_retries
#     408 try:
# --> 409   return call.execute(num_retries=num_retries)
#     410 except googleapiclient.errors.HttpError as e:
#     411   raise _translate_cloud_exception(e)
#
# File ~\.conda\envs\SEB_models\lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\.conda\envs\SEB_models\lib\site-packages\googleapiclient\http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File ~\.conda\envs\SEB_models\lib\site-packages\googleapiclient\http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File ~\.conda\envs\SEB_models\lib\site-packages\google_auth_httplib2.py:218, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     215     body_stream_position = body.tell()
#     217 # Make the request.
# --> 218 response, content = self.http.request(
#     219     uri,
#     220     method,
#     221     body=body,
#     222     headers=request_headers,
#     223     redirections=redirections,
#     224     connection_type=connection_type,
#     225     **kwargs
#     226 )
#     228 # If the response indicated that the credentials needed to be
#     229 # refreshed, then refresh the credentials and re-attempt the
#     230 # request.
#     231 # A stored token may expire between the time it is retrieved and
#     232 # the time the request is made, so we may need to try twice.
#     233 if (
#     234     response.status in self._refresh_status_codes
#     235     and _credential_refresh_attempt < self._max_refresh_attempts
#     236 ):
#
# File ~\.conda\envs\SEB_models\lib\site-packages\ee\_cloud_api_utils.py:71, in _Http.request(***failed resolving arguments***)
#      64 del redirections  # Ignored
#      66 try:
#      67   # googleapiclient is expecting an httplib2 object, and doesn't include
#      68   # requests error in the list of transient errors. Therefore, transient
#      69   # requests errors should be converted to kinds that googleapiclient
#      70   # consider transient.
# ---> 71   response = self._session.request(
#      72       method, uri, data=body, headers=headers, timeout=self._timeout
#      73   )
#      74 except requests.exceptions.ConnectionError as connection_error:
#      75   raise ConnectionError(connection_error) from connection_error
#
# File ~\.conda\envs\SEB_models\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\.conda\envs\SEB_models\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\.conda\envs\SEB_models\lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~\.conda\envs\SEB_models\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\.conda\envs\SEB_models\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\.conda\envs\SEB_models\lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File ~\.conda\envs\SEB_models\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~\.conda\envs\SEB_models\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\.conda\envs\SEB_models\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\.conda\envs\SEB_models\lib\socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File ~\.conda\envs\SEB_models\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~\.conda\envs\SEB_models\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
Map = geemap.Map()
Map.centerObject(vector, zoom=16)

vis_params = {
    'bands': ['B4', 'B3', 'B2'], # False color composite (NIR, Red, Green)
    'min': 0.0,
    'max': 3000,
}

Map.add_layer(S2image, vis_params, "Sentinel2")
# Map.add_layer(vector, {'color': 'FF0000', 'opacity': 0.5}, "BLS")
Map

# %%
start_date = '2024-01-01'
end_date = '2025-01-01'
vector = vector_BLS
S2_BLS = get_s2_sr_cld_col(vector, start_date=start_date, end_date=end_date)
S2_BLS_median = (S2_BLS.map(add_cld_shdw_mask)
                             .map(apply_cld_shdw_mask)
                             .median())

# %%
visParams = {
  'min': 0.0,
  'max': 3000.0,
  'bands': ['B4', 'B3', 'B2'],
}

def visualization(img):
    return img.visualize(visParams).clip(vector)
# Create RGB visualization images for use as animation frames.
rgbVis = S2_BLS.map(visualization)

# %%
gifParams = {
  'region': vector.geometry(),
  'dimensions': 600,
  # 'crs': 'EPSG:3857',
  'framesPerSecond': 10
}

print(rgbVis.getVideoThumbURL(gifParams))
